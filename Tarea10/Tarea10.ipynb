# %% [markdown]
# ## Tarea10
# ## Moreno Puente Emilia Cristina

# %% [markdown]
# Realice las siguientes multiplicaciones matriz-matriz:

# %%
import logging
import numpy as np
from sys import stdout
from datetime import datetime
logging.basicConfig(
level=logging.INFO,
format="[%(asctime)s][%(levelname)s] %(message)s",
stream=stdout,
datefmt="%m-%d %H:%M:%S",
)
logging.info(datetime.now())
A = np.array([[2, -3],
[3, -1]])
B = np.array([[1, 5],
[2, 0]])
C = A @ B
print(C)

# %%
A = np.array([[2, -3, 1],
[4, 3, 0],
[5, 2, -4]])
B = np.array([[0, 1, -2],
[1, 0, -1],
[2, 3, -2]])
C = A @ B
print(C)

# %%
A = np.array([[2, 1, 2],
[-2, 3, 0],
[2, -1, 3]])
B = np.array([[1, -2],
[-4, 1],
[0, 2]])
C = A @ B
print(C)

# %% [markdown]
# Determine cuáles de las siguientes matrices son no singulares y calcule la inversa de esas matrices:

# %%
# %load_ext autoreload
# %autoreload 2
from src import gauss_jordan , matriz_inversa

# %%
A = np.array([[4, 2, 6],
[3, 0, 7],
[-2, -1, -3]])
gauss_jordan(A)

# %%
B = np.array([[1, 2, 0],
[2, 1, -1],
[3, 1, 1]])
gauss_jordan(B)

# %%
B = np.array([[1, 2, 0],
[2, 1, -1],
[3, 1, 1]])
matriz_inversa(B)

# %%
C= np.array([[1, 1, -1, 1],
[1, 2, -4, -2],
[2, 1, 1, 5],
[-1, 0, -2, -4]])
gauss_jordan(C)

# %%
D = np.array([[4, 0, 0, 0],
[6, 7, 0, 0],
[9, 11, 1, 0],
[5, 4, 1, 1]])
gauss_jordan(D)

# %%
D = np.array([[4, 0, 0, 0],
[6, 7, 0, 0],
[9, 11, 1, 0],
[5, 4, 1, 1]])
matriz_inversa(D)

# %% [markdown]
# Resuelva los sistemas lineales 4 x 4 que tienen la misma matriz de coeficientes:

# %% [markdown]
# from src import descomposicion_LU, resolver_LU

# %%
A = np.array([[1, -1, 2, -1],
[1, 0, -1, 1],
[2, 1, 3, -4],
[0, -1, 1, -1]])
L1, U1 = descomposicion_LU(np.array(A))
b1 = np.array([6,4,-2,5])
x1 = resolver_LU(L1, U1, b1)
print("Matriz L:")
print(L1)
print("Matriz U:")
print(U1)
print("Solución del sistema Ax=b:")
print(x1)

# %%
L1, U1 = descomposicion_LU(np.array(A))
b1 = np.array([1,1,2,-1])
x1 = resolver_LU(L1, U1, b1)
print("Matriz L:")
print(L1)
print("Matriz U:")
print(U1)
print("Solución del sistema Ax=b:")
print(x1)

# %%
import sympy as sp
alpha = sp.symbols('alpha')
A = sp.Matrix([
[1, -1, alpha],
[2, 2, 1],
[0, alpha, -sp.Rational(3, 2)]
])
detA = A.det()
print("Determinante:")
sp.pprint(detA)
valores_alpha = sp.solve(detA, alpha)
print("\nValores de alpha que hacen singular la matriz:")
print(valores_alpha)

# %% [markdown]
# Resuelva los siguientes sistemas lineale

# %%
L1 = np.array(
[[1, 0, 0],
[2, 1, 0],
[-1, 0, 1]]
)
L2 = np.array(
[[2, 3, -1],
[0, -2, 1],
[0, 0, 3]]
)
b1 = np.array([2, -1, 1])
x1 = resolver_LU(L1, L2, b1)
print(f'\nLa solución del sistema es:\n{x1}')

# %%
A= np.array([[2, 0, 0],
[-1, 1, 0],
[3, 2, -1]])
B = np.array([[1, 1, 1],
[0, 1, 2],
[0, 0, 1]])
x1 = resolver_LU(L1, L2, b1)
print(f'\nLa solución del sistema es:\n{x1}')

# %% [markdown]
# Factorice las siguientes matrices en la descomposición LU mediante el algoritmo de factorización LU con lii = 1 para todas las i

# %%
X = np.array(
[[2, -1, 1],
[3, 3, 9],
[3,3, 5]]
)
L1, U1 = descomposicion_LU(X)
print("\nDescomposición de la matriz")
print(f"- Matriz L\n{L1}")
print(f"- Matriz U\n{U1}")

# %%
B = np.array([[1.012, -2.132, 3.104],
[-2.132, 4.096, -7.013],
[3.104, -7.013, 0.014]])
L1, U1 = descomposicion_LU(B)
print("\nDescomposición de la matriz")
print(f"- Matriz L\n{L1}")
print(f"- Matriz U\n{U1}")

# %%
C = np.array([[2, 0, 0, 0],
[1, 1.5, 0, 0],
[0, -3, 0.5, 0],
[2, -2, 1, 1]])
L1, U1 = descomposicion_LU(B)
print("\nDescomposición de la matriz")
print(f"- Matriz L\n{L1}")
print(f"- Matriz U\n{U1}")

# %%
D = np.array([[2.1756, 4.0231, -2.1732, 5.1967],
[-4.0231, 6.0000, 0, 1.973],
[-1.0000, -5.2107, 1.1111, 0],
[6.0235, 7.0000, 0, -4.1561]])
L1, U1 = descomposicion_LU(D)
print("\nDescomposición de la matriz")
print(f"- Matriz L\n{L1}")
print(f"- Matriz U\n{U1}")

# %% [markdown]
# Modifique el algoritmo de eliminación gaussiana de tal forma que se pueda utilizar para resolver un sistema lineal usando la descomposición LU y, a continuación, resuelva los siguientes
# sistemas lineales.

# %%
A = np.array([[2,-1,1],
[3,3,9],
[3,3,5]])
L1, U1 = descomposicion_LU(np.array(A))
b1 = np.array([1,0,4])
x1 = resolver_LU(L1, U1, b1)
print("Matriz L:")
print(L1)
print("Matriz U:")
print(U1)
print("Solución del sistema Ax=b:")
print(x1)

# %%
B = np.array([[1.012, -2.132, 3.104],
[-2.132, 4.096, -7.013],
[3.104, -7.013, 0.014]])
L1, U1 = descomposicion_LU(np.array(B))
b1 = np.array([1.984, -5.049, -3.895])
x1 = resolver_LU(L1, U1, b1)
print("Matriz L:")
print(L1)
print("Matriz U:")
print(U1)
print("Solución del sistema Ax=b:")
print(x1)

# %%
D = np.array([[2.1756, 4.0231, -2.1732, 5.1967],
[
-4.0231, 6.0000, 0, 1.973],
[-1.0000, -5.2107, 1.1111, 0],
[6.0235, 7.0000, 0, -4.1561]])
L1, U1 = descomposicion_LU(np.array(D))
b1 = np.array([17.102, -6.1593, 3.0004, 0.0000])
x1 = resolver_LU(L1, U1, b1)
print("Matriz L:")
print(L1)
print("Matriz U:")
print(U1)
print("Solución del sistema Ax=b:")
print(x1)
